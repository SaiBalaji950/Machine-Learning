# %%
Apriori Algorithm

Apriori Algorithm uses frequent itemset to generate the association rule, and it is designed to work
on the databases that contains Transactions. with the help of these association rule, that determines 
how strongly or how weakly two objects are connected. this algorithm uses the Breadth-first-search and
hash tree to calculate the itemset associations efficiently. It is an iterative process for finding the
frequent itemsets from the large datasets.

# %%
Support

Support is the proportion of the transactions in a dataset that contain a specific itemset.
it indicates how frequently an itemset appears in the dataset.

Support Formula:

Support(X)=(Number of transactions containing X)/(Total No.of Transactions)

# %%
Confidence

Confidence is a measure of how often items in a rule appear together. It indicates 
the likelihood of finding the consequent(B) in transactions that contains antecedent(A).

Confidence(A→B)=Support(A∪B)/ Support(A)

# %%
Lift is a measure used in association rule mining to evaluate the strength of a rule 
𝐴
→
𝐵
A→B. It compares the observed support of the rule to the expected support if 
𝐴
A and 
𝐵
B were independent. A lift value greater than 1 indicates a positive association between 
𝐴
A and 
𝐵
B, while a lift less than 1 indicates a negative association.

Definition
Lift is calculated as follows:

Lift(𝐴→𝐵)=Support(𝐴∪𝐵)/(Support(𝐴)×Support(𝐵))

# %%
What is Frequent Itemset

Frequent Itemset are those items whose support greater than threshold value or user specified 
minimum value. it means A & B are frequent itemset each other, then individually A & B both are  
also should be freququent itemset.

Supoose there are two frequent itemset,
A={1,2,3,4,5}
B={2,3,7}
From above two transactions, 2,3 are frequent itemset.

# %%
Steps for Apriori Algorithm

1) Determine the support of itemsets in the transactional databases and then select 
    the minimum support and confidence.
2) Select all the support in the transaction with higher support value than the 
    minimum or selected support value.
3) Find all the rules of these subsets that have higher confidence value then threshold
    or minimum confidence.
4) Sort the rules as the decreasing order of lift.

# %%
Implementation of Apriori Algorithm using Python

# %%
import pandas as pd
a=pd.read_csv('diabetes.csv')
display(a)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
print(a.shape)
# Out:
# (768, 9)

# %%
transactions=[]
for i in range(0,768):
    transactions.append([str(a.values[i,j]) for j in range(0,9)])

# %%
from apyori import apriori

# %%
rules=apriori(transactions=transactions,min_support=0.003,min_confidence=0.2,min_left=3,min_length=2,max_length=2)

# %%
results=list(rules)
print(results)
# Out:
# [RelationRecord(items=frozenset({'0.0'}), support=0.85546875, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'0.0'}), confidence=0.85546875, lift=1.0)]), RelationRecord(items=frozenset({'1.0'}), support=0.4869791666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'1.0'}), confidence=0.4869791666666667, lift=1.0)]), RelationRecord(items=frozenset({'0.141', '0.0'}), support=0.00390625, ordered_statistics=[OrderedStatistic(items_base=frozenset({'0.141'}), items_add=frozenset({'0.0'}), confidence=1.0, lift=1.1689497716894977)]), RelationRecord(items=frozenset({'0.142', '0.0'}), support=0.00390625, ordered_statistics=[OrderedStatistic(items_base=frozenset({'0.142'}), items_add=frozenset({'0.0'}), confidence=1.0, lift=1.1689497716894977)]), RelationRecord(items=frozenset({'0.0', '0.148'}), support=0.00390625, ordered_statistics=[OrderedStatistic(items_base=frozenset({'0.148'}), items_add=frozenset({'0.0'}), confide
# ...

# %%
Visualizing the rule, support, confidence, lift in more clear way:

# %%
for item in results:
    pair=item[0]
    items=[x for x in pair]
    print("Rule:"+items[0]+ "->"+items[1])
    print("Support:"+str(item[1]))
    print("Confidence:"+str(item[2][0][2]))
    print("Lift:"+str(item[2][0][3]))
    print("==============================")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#       2 pair=item[0]
#       3 items=[x for x in pair]
# ----> 4 print("Rule:"+items[0]+ "->"+items[1])
#       5 print("Support:"+str(item[1]))
#       6 print("Confidence:"+str(item[2][0][2]))
#
# IndexError: list index out of range

# %%
for item in results:
    pair=item[0]
    items=[x for x in pair]
    print("Rule:"+items[0]+ "->"+items[0])
    print("Support:"+str(item[1]))
    print("Confidence:"+str(item[2][0][2]))
    print("Lift:"+str(item[2][0][3]))
    print("==============================")
# Out:
# Rule:0.0->0.0
# Support:0.85546875
# Confidence:0.85546875
# Lift:1.0
# ...
# Rule:1.0->1.0
# Support:0.4869791666666667
# Confidence:0.4869791666666667
# Lift:1.0
# ...
# Rule:0.141->0.141
# Support:0.00390625
# Confidence:1.0
# Lift:1.1689497716894977
# ...
# Rule:0.142->0.142
# Support:0.00390625
# Confidence:1.0
# Lift:1.1689497716894977
# ...
# Rule:0.0->0.0
# Support:0.00390625
# Confidence:1.0
# Lift:1.1689497716894977
# ...
# Rule:0.0->0.0
# Support:0.00390625
# Confidence:1.0
# Lift:1.1689497716894977
# ...
# Rule:0.167->0.167
# Support:0.005208333333333333
# Confidence:1.0
# Lift:1.1689497716894977
# ...
# Rule:0.178->0.178
# Support:0.00390625
# Confidence:1.0
# Lift:1.1689497716894977
# ...
# Rule:0.187->0.187
# Support:0.00390625
# Confidence:1.0
# Lift:1.1689497716894977
# ...
# Rule:0.19->0.19
# Support:0.005208333333333333
# Confidence:1.0
# Lift:1.1689497716894977
# ...
# Rule:0.197->0.197
# Support:0.005208333333333333
# Confidence:1.0
# Lift:1.1689497716894977
# ...
# Rule:0.2->0.2
# Support:0.00390625
# Confidence:1.0
# ...
